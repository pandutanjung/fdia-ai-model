# %%
# Mount Google Drive untuk membaca file CSV
import os
from google.colab import drive
drive.mount('/content/drive')

loc = '/content/drive/My Drive/Spark ITB'
os.chdir(loc)

os.getcwd()
# Out:
# Mounted at /content/drive
# '/content/drive/My Drive/Spark ITB'

# %%
# Install XGBoost jika belum terinstall
# !pip install xgboost scikit-learn matplotlib
# !pip install pandas
# !pip install optuna
# !pip install rasterio
# !pip install numpy
# !pip install joblib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.4/364.4 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 68.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('/content/drive/MyDrive/Spark ITB/UKMNCT_IIoT_FDIA.csv')

df =df[~df.isin([np.nan, np.inf, -np.inf]).any(axis=1)]
df.head()
# Out:
#    http_response_body_len  dst_port  dns_rcode  dns_qclass  dns_qtype  \
# 0                0.019536  0.086357   0.495797    0.041017   0.194625
# 1                0.019536  0.188415   0.484033    0.047996   0.212062
# 2                0.019536  0.086357   0.495797    0.041017   0.194625
# 3                0.019536  0.188415   0.484033    0.047996   0.212062
# 4                0.019535  0.004710   0.505208    0.035434   0.180676
#
#    src_port  http_resp_mime_types  http_request_body_len  conn_state  \
# 0  0.183797                   0.7               0.880951    0.217391
# 1  0.394561                   0.7               0.880955    0.217391
# 2  0.183797                   0.7               0.880951    0.217391
# 3  0.394561                   0.7               0.880955    0.217391
# 4  0.015186                   0.7               0.880948    0.217391
#
#    http_user_agent  ...  ssl_established     proto  dns_rejected  dns_RA  \
# ...

# %%
X = df.drop('marker',axis=1)
y = df['marker']

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.2,random_state=21)

df['marker'].value_counts()
# Out:
# marker
# Natural    8688
# Attack     6737
# Name: count, dtype: int64

# %%
df =df[~df.isin([np.nan, np.inf, -np.inf]).any(axis=1)]
df.head()
# Out:
#    http_response_body_len  dst_port  dns_rcode  dns_qclass  dns_qtype  \
# 0                0.019536  0.086357   0.495797    0.041017   0.194625
# 1                0.019536  0.188415   0.484033    0.047996   0.212062
# 2                0.019536  0.086357   0.495797    0.041017   0.194625
# 3                0.019536  0.188415   0.484033    0.047996   0.212062
# 4                0.019535  0.004710   0.505208    0.035434   0.180676
#
#    src_port  http_resp_mime_types  http_request_body_len  conn_state  \
# 0  0.183797                   0.7               0.880951    0.217391
# 1  0.394561                   0.7               0.880955    0.217391
# 2  0.183797                   0.7               0.880951    0.217391
# 3  0.394561                   0.7               0.880955    0.217391
# 4  0.015186                   0.7               0.880948    0.217391
#
#    http_user_agent  ...  ssl_established     proto  dns_rejected  dns_RA  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['marker'] = encoder.fit_transform(df['marker'])
df.head()
# Out:
#    http_response_body_len  dst_port  dns_rcode  dns_qclass  dns_qtype  \
# 0                0.019536  0.086357   0.495797    0.041017   0.194625
# 1                0.019536  0.188415   0.484033    0.047996   0.212062
# 2                0.019536  0.086357   0.495797    0.041017   0.194625
# 3                0.019536  0.188415   0.484033    0.047996   0.212062
# 4                0.019535  0.004710   0.505208    0.035434   0.180676
#
#    src_port  http_resp_mime_types  http_request_body_len  conn_state  \
# 0  0.183797                   0.7               0.880951    0.217391
# 1  0.394561                   0.7               0.880955    0.217391
# 2  0.183797                   0.7               0.880951    0.217391
# 3  0.394561                   0.7               0.880955    0.217391
# 4  0.015186                   0.7               0.880948    0.217391
#
#    http_user_agent  ...  ssl_established     proto  dns_rejected  dns_RA  \
# ...

# %%
import pandas as pd

# Membaca file CSV
df = pd.read_csv('/content/drive/MyDrive/Spark ITB/UKMNCT_IIoT_FDIA.csv')

# Mengatur Pandas agar menampilkan semua baris dan kolom
pd.set_option('display.width', None)  # Menentukan lebar tampilan
pd.set_option('display.max_columns', None)  # Menampilkan semua kolom tanpa pemotongan

# Menampilkan semua data
print(df)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import pandas as pd

# Membaca file CSV
df = pd.read_csv('/content/drive/MyDrive/Spark ITB/UKMNCT_IIoT_FDIA.csv')

# Menampilkan data dengan scrolling horizontal
from IPython.display import display
display(df)
